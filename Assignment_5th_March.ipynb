# %%
"""Q1. How can you create a Bokeh plot using Python code?
Answer:- there are some steps to create a bokeh plot using python code :-
step:1 import bokeh.io
step 2: import bokeh.plotting
step 3: use bokeh.io.output_notebook() function to display bokeh plots directly in a jupyter notebook or jupytenLab
step 4: from bokeh.plotting import figure, output_file, show
step 5: for any sample data use
 from bokeh.sampledata.iris import flowers
and then write a code for creating a plots
"""
# Out:
# 'Q1. How can you create a Bokeh plot using Python code?\nAnswer:- there are some steps to create a bokeh plot using python code :-\nstep:1 import bokeh.io\nstep 2: import bokeh.plotting\nstep 3: use bokeh.io.output_notebook() function to display bokeh plots directly in a jupyter notebook or jupytenLab\nstep 4: from bokeh.plotting import figure, output_file, show\nstep 5: for any sample data use\n from bokeh.sampledata.iris import flowers\nand then write a code for creating a plots\n'

# %%
"""Q2. What are glyphs in Bokeh, and how can you add them to a Bokeh plot? Explain with an example.
Answer:- In Bokeh, glyphs are the visual shapes or markers that are used to represent data points in plots. Glyphs can be lines, circles, squares, triangles, rectangles, or other shapes. They are added to a Bokeh plot using the plot.add_glyph() method or by specifying them directly when creating a glyph-based plot."""
import bokeh.io
import bokeh.plotting
from bokeh.plotting import figure, output_file, show
from bokeh.sampledata.iris import flowers
bokeh.io.output_notebook()
output_file("test.html")
p=figure(title="test flower")
p.xaxis.axis_label="patel_length"
p.yaxis.axis_label="patel_width"
p.circle(flowers['petal_length'], flowers['petal_width'])
show(p)
# Out:
#   <div class="bk-root" id="7e0a7a7d-6993-45c8-beec-7e1e6a0ca069" data-root-id="1002"></div>

# %%
"""Q3. How can you customize the appearance of a Bokeh plot, including the axes, title, and legend?"""
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
from bokeh.plotting import figure, output_file, show
from bokeh.sampledata.iris import flowers
output_file('apperance.html')

p=figure(title="flower_data")
p.xaxis.axis_label="patel_length"
p.yaxis.axis_label="patel_width"
p.circle(flowers['petal_length'], flowers['petal_width'], fill_color="red", legend_label="symbol")
show(p)
# Out:
#   <div class="bk-root" id="3c4672d3-c07f-4456-bd69-3de820132df2" data-root-id="2050"></div>

# %%
"""Q4. What is a Bokeh server, and how can you use it to create interactive plots that can be updated in
real time?
Answer:-
Bokeh server is a component of the Bokeh library that allows you to create and deploy interactive data applications with real-time updating capabilities. With the Bokeh server, you can create web applications that display Bokeh plots and widgets, and these plots and widgets can be updated dynamically as users interact with them.
To use the Bokeh server and create interactive plots with real-time updates, follow these steps:

1 Install Bokeh
2 Import necessary modules:
from bokeh.io import curdoc
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, Slider
from bokeh.layouts import column
3. Create a function to update the plot
4. Create a columnDataSource
5.Create the figure
6. Create the figure
7. Create interactive widgets
8. create the layout
9. add the layout to the document and show the plot
10 Run the Bokeh server

"""
# Out:
# 'Q4. What is a Bokeh server, and how can you use it to create interactive plots that can be updated in\nreal time?\nAnswer:- \nBokeh server is a component of the Bokeh library that allows you to create and deploy interactive data applications with real-time updating capabilities. With the Bokeh server, you can create web applications that display Bokeh plots and widgets, and these plots and widgets can be updated dynamically as users interact with them.\nTo use the Bokeh server and create interactive plots with real-time updates, follow these steps:\n\n1 Install Bokeh\n2 Import necessary modules:\nfrom bokeh.io import curdoc\nfrom bokeh.plotting import figure, show\nfrom bokeh.models import ColumnDataSource, Slider\nfrom bokeh.layouts import column\n3. Create a function to update the plot \n4. Create a columnDataSource\n5.Create the figure\n6. Create the figure\n7. Create interactive widgets\n8. create the layout \n9. add the layout to the document and show the plot \n10 Run the Boke
# ...

# %%
"""Q5. How can you embed a Bokeh plot into a web page or dashboard using Flask or Django?
Answer :there are some steps that uses to embed a bokeh plot into a web page or dashboard using flask or django
Using Flask:

1.Install the required libraries: pip install flask bokeh
2.Create a Flask application file (e.g., app.py).
3.Import the necessary modules: from flask import Flask, render_template
4.Initialize the Flask application: app = Flask(__name__)
5.Define a route to handle the request for the web page: @app.route('/')
6.Create a Bokeh plot as you normally would using the Bokeh library.
7.Use server_document to generate the Bokeh plot script: script = server_document('http://localhost:5006/bokeh_plot')
8.Create an HTML template file (e.g., index.html) that will render the web page.
9.Run the Flask application: flask run

Using Django:

1.Install the required libraries: pip install django bokeh
2.Create a Django project and app.
3.In your Django app, create a view function to handle the request: def index(request):
4.Create a Bokeh plot as you normally would using the Bokeh library.
5.Use server_document to generate the Bokeh plot script: script = server_document('http://localhost:5006/bokeh_plot')
6.Create an HTML template file (e.g., index.html) in the templates directory of your Django app.
7.Configure the URLs for your Django app.
8.Run the Django development server: python manage.py runserver
